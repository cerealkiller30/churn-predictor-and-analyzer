# %% [markdown]
# 1. Take input from user
# 2. Default input parameters: Industry, Timeline (of dataset), Goal (Analysis, Analysis + Prediction)
# 3. Clean the dataset: Interpolate any NULL values, (drop if large enough dataset), label_encoding the classification outputs, set the datatypes, etc.
# 4. Split the dataset (General, 75/25 split)
# 5. A preprocessor will do this.
# 6. Train the model on this dataset
# 7. Accuracy > 90% ALWAYS. lets do this !!
# 8. Visualized EDA
# 9. KPIs of the business (if possible)
# 10. Key Reason for churn
# 11. Highest churn categories etc.
# 12. How to make it better blahblahblah
# 13. If Prediction: Next, input of the prediction SET.

# %%
#THIS NOTEBOOK ONLY BUILDS AND WORKS ON THE MODEL. REST WILL BE HANDLED BY FRONT+BACK END OF THE APP.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv(input_from_user)
